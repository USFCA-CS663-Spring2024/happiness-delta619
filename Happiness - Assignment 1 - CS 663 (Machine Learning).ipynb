# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('DataForTable2.1WHR2023.xls')
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018     3.616480            7.783066        0.775388
# 2195     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2196     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2197     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2199 non-null   object
#  1   year                              2199 non-null   int64
#  2   Life Ladder                       2199 non-null   float64
#  3   Log GDP per capita                2179 non-null   float64
#  4   Social support                    2186 non-null   float64
#  5   Healthy life expectancy at birth  2145 non-null   float64
#  6   Freedom to make life choices      2166 non-null   float64
#  7   Generosity                        2126 non-null   float64
#  8   Perceptions of corruption         2083 non-null   float64
#  9   Positive affect                   2175 non-null   float64
#  10  Negative affect                   2183 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479226            9.389766        0.810679
# std       4.718736     1.125529            1.153387        0.120952
# min    2005.000000     1.281271            5.526723        0.228217
# 25%    2010.000000     4.646750            8.499764        0.746609
# 50%    2014.000000     5.432437            9.498955        0.835535
# 75%    2018.000000     6.309460           10.373216        0.904792
# max    2022.000000     8.018934           11.663788        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294583                      0.747858
# std                            6.901104                      0.140150
# min                            6.720000                      0.257534
# ...

# %% [markdown]
# # Question 1. What is your evaluation of the quality of the data? How large is the dataset? What are the features (columns) and how are they represented? Are there any interesting distributions in the (numeric) features? Are there any interesting correlations in the data? Can you identify any limitations, missing values or distortions of the data? What would you like to see in this dataset?
#
# # Answer - There are 2199 rows in the dataset.
# ##  The following columns are represented in their respective data types.
#     Country name                      2199 non-null   string
#     year                              2199 non-null   int64
#     Life Ladder                       2199 non-null   float64
#     Log GDP per capita                2179 non-null   float64
#     Social support                    2186 non-null   float64
#     Healthy life expectancy at birth  2145 non-null   float64
#     Freedom to make life choices      2166 non-null   float64
#     Generosity                        2126 non-null   float64
#     Perceptions of corruption         2083 non-null   float64
#     Positive affect                   2175 non-null   float64
#     Negative affect                   2183 non-null   float64
#
#
# Features
#
# - Columns represent different happiness and well-being indicators like:
# - Life Ladder: Self-reported life satisfaction
# - Log GDP per capita: Log of GDP per capita
# - Social support: Having someone to count on
# - Healthy life expectancy
# - Perceptions of corruption
# - Positive/negative affect: Experienced positive and negative emotions
# - Features seem to be numerically scored or rated on a reasonable scale.
#
# Interesting Trends
#
# - Life satisfaction declining in recent years for some countries (Afghanistan, Bangladesh)
# - Negative affect increasing for some countries recently
# - GDP not always correlating with higher life evaluation (China vs. Costa Rica for example)
#
# Limitations
#
# - Some missing data points for various countries and years
# - Data could have have biases
#
#
# ## i want to see more countries covering a longer time span

# %%
afg = df[df['Country name'] == 'Afghanistan'][['year', 'Life Ladder']]

bgd = df[df['Country name'] == 'Bangladesh'][['year', 'Life Ladder']]

fig, ax = plt.subplots()

ax.plot(afg['year'], afg['Life Ladder'], label='Afghanistan')

ax.plot(bgd['year'], bgd['Life Ladder'], label='Bangladesh')

ax.set_title('Declining Life Ladder Scores')

ax.set_xlabel('Year')

ax.set_ylabel('Life Ladder Score')

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots() 

countries = ['Afghanistan', 'Australia', 'Germany', 'Mexico']
for country in countries:
    country_df = df[df['Country name'] == country]
    ax.plot(country_df['year'], country_df['Negative affect'], label=country)

ax.set_xlabel('Year')
ax.set_ylabel('Negative Affect Score')
ax.legend(loc='upper left')
ax.set_title('Increasing Negative Affect in Some Countries')

plt.tight_layout()  
plt.show()

# Australia and Germany remain more steady

# %%
china = df[(df['Country name'] == 'China')] 
costa_rica = df[(df['Country name'] == 'Costa Rica')]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(china['year'], china['Log GDP per capita'], 'ro-', label='China')  
ax1.plot(costa_rica['year'], costa_rica['Log GDP per capita'], 'bo-', label='Costa Rica')
ax1.set_title('GDP Per Capita')
ax1.legend()

ax2.plot(china['year'], china['Life Ladder'], 'ro-', label='China')
ax2.plot(costa_rica['year'], costa_rica['Life Ladder'], 'bo-', label='Costa Rica')  
ax2.set_title('Life Ladder Score')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # Question2 . What is the happiest country in 2022? In 2013? Of all time? What is the least happy country in 2022, 2013 and of all time?
#
# ### Happiest countries
# - 2022 -> Finland
# - 2013 -> Canada
# - All time -> Denmark
#
# ### Least Happy countries
#
# - 2022 -> Lebanon
# - 2013 -> Syria
# - All time -> Lebanon

# %% [markdown]
# ## Answer 2.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter data for the year 2022
df_2022 = df[df['year'] == 2022]
df_2022 = df_2022.sort_values(by='Life Ladder', ascending=False)
df_2022_top5 = df_2022[:15]

# Filter data for the year 2013
df_2013 = df[df['year'] == 2013]
df_2013 = df_2013.sort_values(by='Life Ladder', ascending=False)
df_2013_top5 = df_2013[:15]

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

sns.barplot(x='Life Ladder', y='Country name', data=df_2022_top5, palette='viridis', ax=axes[0])
axes[0].set_title('Top Happiest Countries in 2022')
axes[0].set_xlabel('Happiness Score (Life Ladder)')
axes[0].set_ylabel('Country')

sns.barplot(x='Life Ladder', y='Country name', data=df_2013_top5, palette='viridis', ax=axes[1])
axes[1].set_title('Top Happiest Countries in 2013')
axes[1].set_xlabel('Happiness Score (Life Ladder)')
axes[1].set_ylabel('Country')

plt.tight_layout()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df_all_time = df.sort_values(by='Life Ladder', ascending=False)
df_all_time_top5 = df_all_time[:20]

plt.figure(figsize=(12, 6))
sns.barplot(x='Life Ladder', y='Country name', data=df_all_time_top5, palette='pastel')

plt.xlabel('Average Happiness Score (Life Ladder)')
plt.ylabel('Country')
plt.title('Happiest Countries of All Time')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df_2022 = df[df['year'] == 2022]
df_2022 = df_2022.sort_values(by='Life Ladder', ascending=True)
df_2022_top5 = df_2022[:15]

df_2013 = df[df['year'] == 2013]
df_2013 = df_2013.sort_values(by='Life Ladder', ascending=True)
df_2013_top5 = df_2013[:15]

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

sns.barplot(x='Life Ladder', y='Country name', data=df_2022_top5, palette='viridis', ax=axes[0])
axes[0].set_title('Least Happiest Countries in 2022')
axes[0].set_xlabel('Happiness Score (Life Ladder)')
axes[0].set_ylabel('Country')

sns.barplot(x='Life Ladder', y='Country name', data=df_2013_top5, palette='viridis', ax=axes[1])
axes[1].set_title('Least Happiest Countries in 2013')
axes[1].set_xlabel('Happiness Score (Life Ladder)')
axes[1].set_ylabel('Country')

plt.tight_layout()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df_all_time = df.sort_values(by='Life Ladder', ascending=True)
df_all_time_top5 = df_all_time[:20]

plt.figure(figsize=(12, 6))
sns.barplot(x='Life Ladder', y='Country name', data=df_all_time_top5, palette='pastel')

plt.xlabel('Average Happiness Score (Life Ladder)')
plt.ylabel('Country')
plt.title('Least Happiest Countries of All Time')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Corrected Answer 3 below

# %%
df = pd.read_excel('DataForTable2.1WHR2023.xls')
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018     3.616480            7.783066        0.775388
# 2195     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2196     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2197     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
import matplotlib.pyplot as plt

df['start_year'] = df.groupby('Country name')['year'].transform('min')
df['end_year'] = df.groupby('Country name')['year'].transform('max')
df['increase_in_happiness'] = df.groupby('Country name')['Life Ladder'].transform(lambda x: x.iloc[-1] - x.iloc[0])

result_df = df[['Country name', 'start_year', 'end_year', 'increase_in_happiness']].drop_duplicates()

result_df = result_df.sort_values(by='increase_in_happiness', ascending=False)


most_increase = result_df.head(5)
most_decrease = result_df.tail(5)

plt.figure(figsize=(12, 8))
plt.bar(most_increase['Country name'], most_increase['increase_in_happiness'], color='green')
plt.xlabel('Country')
plt.ylabel('Increase in Happiness')
plt.title('Top 5 Countries with the Most Increase in Happiness from starting occurence to 2022')
plt.tight_layout()

plt.show()

plt.figure(figsize=(12, 8))
plt.bar(most_decrease['Country name'], most_decrease['increase_in_happiness'], color='red')
plt.xlabel('Country')
plt.ylabel('Decrease in Happiness')
plt.title('Top 5 Countries with the Most Decrease in Happiness from starting occurence to 2022')
plt.tight_layout()

plt.show()

result_df
# Out:
#              Country name  start_year  end_year  increase_in_happiness
# 421   Congo (Brazzaville)        2008      2022               1.985126
# 1412            Nicaragua        2006      2022               1.932099
# 671               Georgia        2006      2022               1.617647
# 259              Bulgaria        2007      2022               1.534551
# 1682               Serbia        2007      2021               1.494884
# ...                   ...         ...       ...                    ...
# 39                 Angola        2011      2014              -1.794163
# 1878                Syria        2008      2015              -1.861419
# 980                Jordan        2005      2022              -1.939054
# 0             Afghanistan        2008      2022              -2.442319
# 1101              Lebanon        2005      2022              -3.138818
#
# [165 rows x 4 columns]

# %% [markdown]
# # Countries who are have provided data for the years 2005 and 2022,
# ## The max difference in life ladder form the start of participation to 2022 have been observed by the following countries.
# ### Max increase -> Congo(Brazzaville) , an increase of 1.985126 units
# ### Max decrease -> Lebanon, a decrease of 3.138818 units ≡ -3.138818 units
